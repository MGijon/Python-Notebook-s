# %%
import pandas as pd
import gensim 
import scipy as cp
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load Google's pre-trained Word2Vec model
model = gensim.models.KeyedVectors.load_word2vec_format('Data/GoogleNews-vectors-negative300.bin', binary=True)

# %%
# genre maculine sustraction: 'king'
print(model.most_similar(positive = ['king', 'women'], negative = ['men'], topn = 1))
# Out:
# [('queen', 0.6525817513465881)]

# %%
# genre femenine sustraction: 'king'
print(model.most_similar(positive = ['king', 'men'], negative = ['women'], topn = 1))
# Out:
# [('kings', 0.6467224359512329)]

# %%
word = 'king'
Tope = 10
lista_valoresM = []
for i in model.most_similar( positive = [word, 'women'], negative = ['men'], topn = Tope):
    lista_valoresM.append(i[1])
lista_valoresF = []
for i in model.most_similar(positive = [word, 'men'], negative = ['women'], topn = Tope):
    lista_valoresF.append(i[1])
    
plt.figure(figsize = (20, 7))
plt.scatter([x for x in range(0, len(lista_valoresM))], lista_valoresM, color = 'red', label = 'Men sustraction')
plt.scatter([x for x in range(0, len(lista_valoresF))], lista_valoresF, color = 'green', label = 'Women sustraction')
plt.plot(lista_valoresM, color = 'red')
plt.plot(lista_valoresF, color = 'green')
plt.title('Most similar values for ' + word)
plt.legend()

# %%
word = 'brave'
Tope = 10
lista_valoresM = []
for i in model.most_similar( positive = [word, 'women'], negative = ['men'], topn = Tope):
    lista_valoresM.append(i[1])
lista_valoresF = []
for i in model.most_similar(positive = [word, 'men'], negative = ['women'], topn = Tope):
    lista_valoresF.append(i[1])
    
plt.figure(figsize = (20, 7))
plt.scatter([x for x in range(0, len(lista_valoresM))], lista_valoresM, color = 'red', label = 'Men sustraction')
plt.scatter([x for x in range(0, len(lista_valoresF))], lista_valoresF, color = 'green', label = 'Women sustraction')
plt.plot(lista_valoresM, color = 'red')
plt.plot(lista_valoresF, color = 'green')
plt.title('Most similar values for ' + word)
plt.legend()

# %%
word = 'kind'
Tope = 10
lista_valoresM = []
for i in model.most_similar( positive = [word, 'women'], negative = ['men'], topn = Tope):
    lista_valoresM.append(i[1])
lista_valoresF = []
for i in model.most_similar(positive = [word, 'men'], negative = ['women'], topn = Tope):
    lista_valoresF.append(i[1])
    
plt.figure(figsize = (20, 7))
plt.scatter([x for x in range(0, len(lista_valoresM))], lista_valoresM, color = 'red', label = 'Men sustraction')
plt.scatter([x for x in range(0, len(lista_valoresF))], lista_valoresF, color = 'green', label = 'Women sustraction')
plt.plot(lista_valoresM, color = 'red')
plt.plot(lista_valoresF, color = 'green')
plt.title('Most similar values for ' + word)
plt.legend()

# %%
word = 'computer_programmer'
Tope = 10
lista_valoresM = []
for i in model.most_similar( positive = [word, 'women'], negative = ['men'], topn = Tope):
    lista_valoresM.append(i[1])
lista_valoresF = []
for i in model.most_similar(positive = [word, 'men'], negative = ['women'], topn = Tope):
    lista_valoresF.append(i[1])
    
plt.figure(figsize = (20, 7))
plt.scatter([x for x in range(0, len(lista_valoresM))], lista_valoresM, color = 'red', label = 'Men sustraction')
plt.scatter([x for x in range(0, len(lista_valoresF))], lista_valoresF, color = 'green', label = 'Women sustraction')
plt.plot(lista_valoresM, color = 'red')
plt.plot(lista_valoresF, color = 'green')
plt.title('Most similar values for ' + word)
plt.legend()

# %%
word = 'king'
Tope = 10
lista_valoresM = []
palabras_M = []
for i in model.most_similar( positive = [word, 'women'], negative = ['men'], topn = Tope):
    lista_valoresM.append(i[1])
    palabras_M.append(i[0])
lista_valoresF = []
palabras_F = []
for i in model.most_similar(positive = [word, 'men'], negative = ['women'], topn = Tope):
    lista_valoresF.append(i[1])
    palabras_F.append(i[0])
    
plt.figure(figsize = (25, 10))
plt.scatter([x for x in range(0, len(lista_valoresM))], lista_valoresM, color = 'red', label = 'Men sustraction')
plt.scatter([x for x in range(0, len(lista_valoresF))], lista_valoresF, color = 'green', label = 'Women sustraction')
plt.plot(lista_valoresM, color = 'red')
plt.plot(lista_valoresF, color = 'green')
for i in range(0, len(palabras_M)):
    plt.annotate(palabras_M[i], xy = (i, lista_valoresM[i]), xytext = (i, lista_valoresM[i]))
for i in range(0, len(palabras_F)):
    plt.annotate(palabras_F[i], xy = (i, lista_valoresF[i]), xytext = (i, lista_valoresF[i]))
plt.title('Most similar values for ' + word)
plt.legend()

# %%
word = 'sex'
Tope = 10
lista_valoresM = []
palabras_M = []
for i in model.most_similar( positive = [word, 'women'], negative = ['men'], topn = Tope):
    lista_valoresM.append(i[1])
    palabras_M.append(i[0])
lista_valoresF = []
palabras_F = []
for i in model.most_similar(positive = [word, 'men'], negative = ['women'], topn = Tope):
    lista_valoresF.append(i[1])
    palabras_F.append(i[0])
    
plt.figure(figsize = (25, 10))
plt.scatter([x for x in range(0, len(lista_valoresM))], lista_valoresM, color = 'red', label = 'Men sustraction')
plt.scatter([x for x in range(0, len(lista_valoresF))], lista_valoresF, color = 'green', label = 'Women sustraction')
plt.plot(lista_valoresM, color = 'red')
plt.plot(lista_valoresF, color = 'green')
for i in range(0, len(palabras_M)):
    plt.annotate(palabras_M[i], xy = (i, lista_valoresM[i]), xytext = (i, lista_valoresM[i]))
for i in range(0, len(palabras_F)):
    plt.annotate(palabras_F[i], xy = (i, lista_valoresF[i]), xytext = (i, lista_valoresF[i]))
plt.title('Most similar values for ' + word)
plt.legend()

# %%
word = 'power'
Tope = 10
lista_valoresM = []
palabras_M = []
for i in model.most_similar( positive = [word, 'women'], negative = ['men'], topn = Tope):
    lista_valoresM.append(i[1])
    palabras_M.append(i[0])
lista_valoresF = []
palabras_F = []
for i in model.most_similar(positive = [word, 'men'], negative = ['women'], topn = Tope):
    lista_valoresF.append(i[1])
    palabras_F.append(i[0])
    
plt.figure(figsize = (25, 10))
plt.scatter([x for x in range(0, len(lista_valoresM))], lista_valoresM, color = 'red', label = 'Men sustraction')
plt.scatter([x for x in range(0, len(lista_valoresF))], lista_valoresF, color = 'green', label = 'Women sustraction')
plt.plot(lista_valoresM, color = 'red')
plt.plot(lista_valoresF, color = 'green')
for i in range(0, len(palabras_M)):
    plt.annotate(palabras_M[i], xy = (i, lista_valoresM[i]), xytext = (i, lista_valoresM[i]))
for i in range(0, len(palabras_F)):
    plt.annotate(palabras_F[i], xy = (i, lista_valoresF[i]), xytext = (i, lista_valoresF[i]))
plt.title('Most similar values for ' + word)
plt.legend()

# %%
word = 'brave'
Tope = 10
lista_valoresM = []
palabras_M = []
for i in model.most_similar( positive = [word, 'women'], negative = ['men'], topn = Tope):
    lista_valoresM.append(i[1])
    palabras_M.append(i[0])
lista_valoresF = []
palabras_F = []
for i in model.most_similar(positive = [word, 'men'], negative = ['women'], topn = Tope):
    lista_valoresF.append(i[1])
    palabras_F.append(i[0])
    
plt.figure(figsize = (25, 10))
plt.scatter([x for x in range(0, len(lista_valoresM))], lista_valoresM, color = 'red', label = 'Men sustraction')
plt.scatter([x for x in range(0, len(lista_valoresF))], lista_valoresF, color = 'green', label = 'Women sustraction')
plt.plot(lista_valoresM, color = 'red')
plt.plot(lista_valoresF, color = 'green')
for i in range(0, len(palabras_M)):
    plt.annotate(palabras_M[i], xy = (i, lista_valoresM[i]), xytext = (i, lista_valoresM[i]))
for i in range(0, len(palabras_F)):
    plt.annotate(palabras_F[i], xy = (i, lista_valoresF[i]), xytext = (i, lista_valoresF[i]))
plt.title('Most similar values for ' + word)
plt.legend()

# %%
# comparar las similutudes entre palabras de las listas: explicar mejor
def palabras_iguales(word, Tope = 5, imprimir = False):
    listaM = []
    listaF = []
    for i in model.most_similar(positive = [word, 'men'], negative = ['women'], topn = Tope):
        listaF.append(i[0])
    for i in model.most_similar(positive = [word, 'women'], negative = ['men'], topn = Tope):
        listaM.append(i[0])
    if imprimir == True:
        print(set(listaM))
        print('\n')
        print(set(listaF))
        print('\n')
        print(set(listaM) & set(listaF))
    return set(listaM) & set(listaF)
def palabas_iguales_count(word, Tope = 5):
    return len(palabras_iguales(word, Tope))

# %%
# veamos como crece o disminuye el número de palabras iguales según aunentamos el número del conjunto
palabra = 'king'
Tope = 20
numero_iguales = []
eje_x = [x for x in range(1, Tope + 1)]
for i in eje_x:
    numero_iguales.append(palabas_iguales_count(palabra, i))

plt.axis('auto')
plt.scatter(eje_x, numero_iguales , color = 'red', label = 'Common words')
plt.plot(eje_x, eje_x, color = 'blue', label = 'Upper bound')
plt.title('Number of similar words between back and fort for ' + palabra)
plt.xlabel('Size of the sample')
plt.ylabel('Number of common words')
plt.legend()

# %%
# veamos como crece o disminuye el número de palabras iguales según aunentamos el número del conjunto
palabra = 'sex'
Tope = 20
numero_iguales = []
eje_x = [x for x in range(1, Tope + 1)]
for i in eje_x:
    numero_iguales.append(palabas_iguales_count(palabra, i))

plt.axis('auto')
plt.scatter(eje_x, numero_iguales , color = 'red', label = 'Common words')
plt.plot(eje_x, eje_x, color = 'blue', label = 'Upper bound')
plt.title('Number of similar words between back and fort for ' + palabra)
plt.xlabel('Size of the sample')
plt.ylabel('Number of common words')
plt.legend()

# %%
# veamos como crece o disminuye el número de palabras iguales según aunentamos el número del conjunto
palabra = 'brave' 
Tope = 20
numero_iguales = []
eje_x = [x for x in range(1, Tope + 1)]
for i in eje_x:
    numero_iguales.append(palabas_iguales_count(palabra, i))

plt.axis('auto')
plt.scatter(eje_x, numero_iguales , color = 'red', label = 'Common words')
plt.plot(eje_x, eje_x, color = 'blue', label = 'Upper bound')
plt.title('Number of similar words between back and fort for ' + palabra)
plt.xlabel('Size of the sample')
plt.ylabel('Number of common words')
plt.legend()

# %%
# veamos como crece o disminuye el número de palabras iguales según aunentamos el número del conjunto
palabra = 'brave' 
Tope = 4
numero_iguales = []
eje_x = [x for x in range(1, Tope + 1)]
for i in eje_x:
    numero_iguales.append(palabas_iguales_count(palabra, i))

plt.axis('auto')
plt.scatter(eje_x, numero_iguales , color = 'red', label = 'Common words')
plt.plot(eje_x, eje_x, color = 'blue', label = 'Upper bound')
plt.title('Number of similar words between back and fort for ' + palabra)
plt.xlabel('Size of the sample')
plt.ylabel('Number of common words')
plt.legend()

# %%
Tope = 4
for i in range(1, Tope): 
    palabras_iguales('brave', i, True)
    print('======= \n')
# WOW, las palabras aparecen cambiadas de orden, no con 2 pero si con tres por que la que no aperecía en A aparece y vicebersa
# Out:
# {'courageous'}
#
#
# {'courageous'}
#
#
# {'courageous'}
# =======
#
# {'bravely', 'courageous'}
#
#
# {'bravest', 'courageous'}
#
#
# {'courageous'}
# =======
#
# {'bravely', 'bravest', 'courageous'}
#
#
# {'bravely', 'bravest', 'courageous'}
#
#
# {'bravely', 'bravest', 'courageous'}
# =======

# %%
# veamos como crece o disminuye el número de palabras iguales según aunentamos el número del conjunto
palabra = 'thing'
Tope = 20
numero_iguales = []
eje_x = [x for x in range(1, Tope + 1)]
for i in eje_x:
    numero_iguales.append(palabas_iguales_count(palabra, i))

plt.axis('auto')
plt.scatter(eje_x, numero_iguales , color = 'red', label = 'Common words')
plt.plot(eje_x, eje_x, color = 'blue', label = 'Upper bound')
plt.title('Number of similar words between back and fort for ' + palabra)
plt.xlabel('Size of the sample')
plt.ylabel('Number of common words')
plt.legend()

# %%
# ahora estudiaré la relación de ida y vuelta para un solo resultado
def BF(palabra):
    ida = model.most_similar(positive = [palabra, 'women'], negative = ['men'], topn = 1)
    vuelta = model.most_similar(positive = [ida[0], 'men'], negative = ['women'], topn = 1)
    return (palabra, ida, vuelta)

# %%
BF('king')
# Out:
# ('king', [('queen', 0.6525817513465881)], [('king', 0.5722486972808838)])

# %%
BF('sex')
# Out:
# ('sex', [('sexual', 0.6333349943161011)], [('lewd', 0.492270827293396)])

# %%
def vuelve_al_mismo_sitio(palabra):
    value = False
    tupla_ = BF(palabra)
    if palabra == tupla_[2][0][0]:
        value = True
    return value

# %%
vuelve_al_mismo_sitio('king')
# Out:
# True

# %%
vuelve_al_mismo_sitio('sex')
# Out:
# False

# %%
# from sklearn.descomposition import PCA ESTO QUEDA PARA MÁS TARDE..., NECESITO INSTALAR ESTO
# instalar tambiéwn wordnet y seaborn
